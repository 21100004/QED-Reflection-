# %%
import qed

# %%
mirrorLen = 10
fig = qed.makeMirror(mirrorLen)

# %%
mirrorLen = 10
numPiece = 10
fig = qed.divideMirror(mirrorLen, numPiece)

# %%
sourceX = 0
sourceY = 10
photoX = 10
photoY = 10
mirrorLen = 10
numPiece = 10
fig = qed.placeSAndP(sourceX, sourceY, photoX, photoY, mirrorLen, numPiece)

# %%
mirrorLen = 10
numPiece = 10
sourceX = 0
sourceY = 10
photoX = 10
photoY = 10
fig = qed.classicalPath(mirrorLen, numPiece, sourceX, sourceY, photoX, photoY)

# %%
mirrorLen = 10
numPiece = 10
sourceX = 0
sourceY = 10
photoX = 10
photoY = 10
qed.QEDPath(mirrorLen, numPiece, sourceX, sourceY, photoX, photoY)

# %%
mirrorLen = 10
numPiece = 10
sourceX = 0
sourceY = 10
photoX = 10
photoY = 10
speed = 3*10**8
times = qed.createTimes(mirrorLen, numPiece, sourceX, sourceY, photoX, photoY,
                    speed)

# %%
mirrorLen = 10
numPiece = 10
times = qed.createTimes(mirrorLen, numPiece, sourceX, sourceY, photoX, photoY,
                    speed)
qed.plotTimes(mirrorLen, numPiece, times)

# %%
amp = 2
phase = 60
qed.phasor(amp, phase)

# %%
amp = 2
phase = 0
freq = 1
time = 0.125
qed.timePhasor(amp, phase, freq, time)

# %%
mirrorLen = 10
numPiece = 1000
sourceX = 0
sourceY = 500
photoX = 10
photoY = 500
speed = 3*10**8
lightFreq = 750*10**12
times = qed.createTimes(mirrorLen, numPiece, sourceX, sourceY, photoX, photoY,
                    speed)
comp, reals, imags, z = qed.phasorsOnMirror(mirrorLen, numPiece, times, lightFreq)
qed.addPhasors(numPiece, reals, imags, z)
